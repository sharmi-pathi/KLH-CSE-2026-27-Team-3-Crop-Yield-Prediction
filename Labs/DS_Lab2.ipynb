# %%
import pandas as pd
import numpy as np
#sample-dataset
df = pd.DataFrame({ 'Age': [25,30,np.nan, 40, 35], 
                    'Department': ['HR', 'Finance', 'Finance', np.nan, 'IT']})
print(df)
#mean
df['Age']=df['Age'].fillna(df['Age'].mean())
#mode
df['Department']=df['Department'].fillna(df['Department'].mode()[0])
print(df)
# Out:
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2   NaN    Finance
# 3  40.0        NaN
# 4  35.0         IT
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2  32.5    Finance
# 3  40.0    Finance
# 4  35.0         IT

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({ 'Age': [25,30,np.nan, 40, 35], 
                    'Department': ['HR', 'Finance', 'Finance', np.nan, 'IT']})
print("Original DataSet (with missing values):")
print(df)
#forward fill
df_ffill = df.copy()
df_ffill.ffill(inplace=True)
print(df_ffill)
# Out:
# Original DataSet (with missing values):
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2   NaN    Finance
# 3  40.0        NaN
# 4  35.0         IT
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2  30.0    Finance
# 3  40.0    Finance
# 4  35.0         IT

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({ 'Age': [25,30,np.nan, 40, 35], 
                    'Department': ['HR', 'Finance', 'Finance', np.nan, 'IT']})
print("Original DataSet (with missing values):")
print(df)
#backward fill
df_bfill = df.copy()
df_bfill.bfill(inplace=True)
print(df_bfill)
# Out:
# Original DataSet (with missing values):
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2   NaN    Finance
# 3  40.0        NaN
# 4  35.0         IT
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2  40.0    Finance
# 3  40.0         IT
# 4  35.0         IT

# %%
import pandas as pd
import numpy as np 
df = pd.DataFrame({ 'Age': [25,30,np.nan, 40, 35], 
                    'Department': ['HR', 'Finance', 'Finance', np.nan, 'IT']})
print("Original Dataset")
print(df)
df_drop_rows = df.dropna()
print("After Dropping:\n", df_drop_rows)
# Out:
# Original Dataset
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2   NaN    Finance
# 3  40.0        NaN
# 4  35.0         IT
# After Dropping:
#      Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 4  35.0         IT

# %%
df_drop_cols = df.dropna(axis=1)
print("After dropping columns:\n",df_drop_cols)
# Out:
# After dropping columns:
#  Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
df_drop_cols = df.dropna(axis=0)
print("After dropping columns:\n",df_drop_cols)
# Out:
# After dropping columns:
#      Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 4  35.0         IT

# %%
#removing duplicates 
import pandas as pd
df=pd.DataFrame({ 'ID' : [1,2,2,3,4,4], 'Name' : ['Alice', 'Bob', 'Bob', 'Charlie', 'David', 'David'],
                  'Age' : [25,30,30,35,40,40] })
print(df)
df_exact = df.drop_duplicates()
print("\nAfter Exact Match Removal:\n", df_exact)
# Out:
#    ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 2   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40
# 5   4    David   40
#
# After Exact Match Removal:
#     ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40

# %%
#subset based removal
import pandas as pd
df=pd.DataFrame({ 'ID' : [1,2,2,3,4,4], 'Name' : ['Alice', 'Bob', 'Bob', 'Charlie', 'David', 'David'],
                  'Age' : [25,30,30,35,40,40] })
print(df)
df_subset_id = df.drop_duplicates(subset=['ID'])
print("After subset rmeoval\n", df_subset_id)
df_subset_name = df.drop_duplicates(subset=['Name'])
print("After subset rmeoval\n", df_subset_name)
# Out:
#    ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 2   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40
# 5   4    David   40
# After subset rmeoval
#     ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40
# After subset rmeoval
#     ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40

# %%
import pandas as pd
df = pd.DataFrame({ 'Date': ['2025-01-05', '05/01/2025', 'Jan 5, 2025' , '2025.01.05'] })
print("Original\n",df)
df['Date']=pd.to_datetime(df['Date'], errors='coerce').dt.strftime('%Y-%m-%d')
print(df)
# Out:
# Original
#            Date
# 0   2025-01-05
# 1   05/01/2025
# 2  Jan 5, 2025
# 3   2025.01.05
#          Date
# 0  2025-01-05
# 1         NaN
# 2         NaN
# 3         NaN

# %%
df=pd.DataFrame({ 'Name': ['Alice','Bob','Charlie','DAVID']})
df['Name_lower'] = df['Name'].str.lower()
df['Name_upper'] = df['Name'].str.upper()
print(df)
# Out:
#       Name Name_lower Name_upper
# 0    Alice      alice      ALICE
# 1      Bob        bob        BOB
# 2  Charlie    charlie    CHARLIE
# 3    DAVID      david      DAVID
